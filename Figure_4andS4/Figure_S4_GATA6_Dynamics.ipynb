# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from re import match
import os
import numpy as np
import seaborn as sns
import math

import seaborn as sns
import scipy as sp

# %%
ingeo_colours = ["#0077BB","#33BBEE","#009988","#EE7733","#CC3311","#EE3377","#BBBBBB","#5D54A4"]

# %%
## Batch 3

# %%
B8 = pd.read_csv("Batch_3_tracks/B8.csv")
C8P2a = pd.read_csv("Batch_3_tracks/C8P2a.csv")
C8P2b = pd.read_csv("Batch_3_tracks/C8P2b.csv")

# %%
df_3 = pd.concat([B8, C8P2a, C8P2b])
df_3['Status'] = 'FOXC1+SOX17+GATA6+'

# %%
df_3['Batch'] = 'Batch_3'

# %%
## Batch 2

# %%
F4 = pd.read_csv("Batch_2_tracks/F4_P2.csv")
G5_P2 = pd.read_csv("Batch_2_tracks/G5_P2.csv")
G5_P1 = pd.read_csv("Batch_2_tracks/G5_P1.csv")
G7_P1 = pd.read_csv("Batch_2_tracks/G7_P1.csv")

# %%
F4.loc[F4['TRACK_ID'] == 183, 'Status'] = 'FOXC1+SOX17+GATA6+'
F4.loc[F4['TRACK_ID'] == 213, 'Status'] = 'FOXC1+SOX17-GATA6+'
G5_P1.loc[G5_P1['TRACK_ID'] == 8, 'Status'] = 'FOXC1+SOX17-GATA6+'
G5_P2.loc[G5_P2['TRACK_ID'] == 72, 'Status'] = 'FOXC1-SOX17+GATA6+'
G5_P2.loc[G5_P2['TRACK_ID'] == 83, 'Status'] = 'FOXC1-SOX17+GATA6+'

# %%
df_2 = pd.concat([F4, G5_P2, G5_P1, G7_P1])

# %%
df_2['Batch'] = 'Batch_2'

# %%
df = pd.concat([df_2, df_3])

# %%
df_toplot = df.loc[df['Batch']=='Batch_2']

# %%
plt.figure(figsize=(4,4), dpi=100)
sns.set_theme(style="ticks")


ax = sns.lineplot(x="time_hr", y="MEAN_INTENSITY_CH2",
             hue="LABEL",
             data=df_toplot, palette ="muted")

plt.xlabel(f'Time (hours)')
plt.ylabel(f'mean Achilles Expression')
plt.grid()  #just add this

ax.get_legend().remove()

#plt.savefig(f'alltracks.png', dpi = 300, bbox_inches='tight')

# %%
plt.figure(figsize=(4,4), dpi=100)
sns.set_theme(style="ticks")


ax = sns.lineplot(x="time_hr", y="MEAN_INTENSITY_CH2",
             data=df_toplot, color = 'darkgrey')

plt.xlabel(f'Time (hours)')
plt.ylabel(f'mean Achilles Expression')
plt.grid()  #just add this
#plt.savefig(f'alltracks_mean.png', dpi = 300, bbox_inches='tight')

# %%
df_toplot
# Out:
#            LABEL     ID  TRACK_ID   QUALITY  POSITION_X  POSITION_Y  \
# 0      Track_213   2056       213  0.813871  662.779704  621.596321
# 1      Track_183   2059       183  0.808491  631.854094  619.659135
# 2      Track_213   2104       213  0.910330  652.180999  622.522517
# 3      Track_183   2152       183  0.806586  630.428490  620.002458
# 4      Track_213   2237       213  0.842313  651.712155  622.507103
# ..           ...    ...       ...       ...         ...         ...
# 675  Track_57.bb  13905        57  0.933913  214.761241  415.569226
# 676  Track_57.aa  13906        57  0.932597   92.590879  491.287380
# 677  Track_57.ba  13912        57  0.917757  356.074083  646.511034
# 678   Track_8.bb  13919         8  0.904747  236.085823  650.618730
# 679   Track_8.aa  13925         8  0.897331   63.868024  572.023646
#
#      POSITION_Z  POSITION_T  FRAME    RADIUS  ...              Status  \
# 0             0           0      0  5.532844  ...  FOXC1+SOX17-GATA6+
# ...

# %%
plt.figure(figsize=(4,4), dpi=100)
sns.set_theme(style="ticks")


ax = sns.lineplot(x="time_hr", y="MEAN_INTENSITY_CH2", hue="Status",
             data=df_toplot, palette =[ingeo_colours[4], ingeo_colours[0], ingeo_colours[0]] )

plt.xlabel(f'Time (hours)')
plt.ylabel(f'mean Achilles Expression')
plt.grid()  #just add this

ax.get_legend().remove()

#plt.savefig(f'alltracks_mean_by_endstate.pdf', dpi = 300, bbox_inches='tight')

# %%
plt.figure(figsize=(4,4), dpi=100)
sns.set_theme(style="ticks")


ax = sns.lineplot(x="time_hr", y="MEAN_INTENSITY_CH2", hue='LABEL',
             data=df_toplot.loc[df_toplot['Status']=='FOXC1-SOX17+GATA6+'], palette ="Blues", legend=False).set(ylim=(0,550), xlim=(52,96))
plt.xlabel(f'Time (hours)')
plt.ylabel(f'mean Achilles Expression')
plt.grid()  #just add this

#plt.savefig(f'alltracks_mean_by_endstate_SOX17+FOXC1-.pdf', dpi = 300, bbox_inches='tight')

# %%
plt.figure(figsize=(4,4), dpi=100)
sns.set_theme(style="ticks")


ax = sns.lineplot(x="time_hr", y="MEAN_INTENSITY_CH2", hue='LABEL',
             data=df_toplot.loc[df_toplot['Status']=='FOXC1+SOX17+GATA6+'], palette ="Blues", legend=False).set(ylim=(0,550), xlim=(52,96))
plt.xlabel(f'Time (hours)')
plt.ylabel(f'mean Achilles Expression')
plt.grid()  #just add this

#plt.savefig(f'alltracks_mean_by_endstate_SOX17+FOXC1+.pdf', dpi = 300, bbox_inches='tight')

# %%
plt.figure(figsize=(4,4), dpi=100)
sns.set_theme(style="ticks")


ax = sns.lineplot(x="time_hr", y="MEAN_INTENSITY_CH2", hue='LABEL',
             data=df_toplot.loc[df_toplot['Status']=='FOXC1+SOX17-GATA6+'], palette ="Reds", legend=False).set(ylim=(0,550), xlim=(52,96))
plt.xlabel(f'Time (hours)')
plt.ylabel(f'mean Achilles Expression')
plt.grid()  #just add this

#plt.savefig(f'alltracks_mean_by_endstate_SOX17-FOXC1+.pdf', dpi = 300, bbox_inches='tight')

# %%
df_toplot.loc[df_toplot['TRACK_ID']==183]
# Out:
#             LABEL     ID  TRACK_ID   QUALITY  POSITION_X  POSITION_Y  \
# 1       Track_183   2059       183  0.808491  631.854094  619.659135
# 3       Track_183   2152       183  0.806586  630.428490  620.002458
# 5       Track_183   2240       183  0.834837  632.866893  617.134391
# 7       Track_183   2286       183  0.941052  630.546680  618.422535
# 9       Track_183   2429       183  0.857447  629.859938  618.378155
# ..            ...    ...       ...       ...         ...         ...
# 341  Track_183.aa  24046       183  0.921900  552.929686  612.821857
# 342  Track_183.ab  24349       183  0.889466  473.701953  588.688411
# 344  Track_183.aa  24460       183  0.812809  548.394364  610.262624
# 346  Track_183.aa  24736       183  0.726465  542.598990  606.500486
# 347  Track_183.ab  24551       183  0.908578  472.311523  587.111922
#
#      POSITION_Z  POSITION_T  FRAME    RADIUS  ...              Status  \
# ...

# %%
## FOXC1+SOX17+ 213 (One track)

## FOXC1+SOX17+ 183 AB

## FOXC1-SOX17+ 72 BA

# %%
track = 72
end_clone = 'ba'

df_toplot_ = df_toplot.loc[df_toplot['TRACK_ID']==track]
root = df_toplot_.loc[df_toplot_['LABEL']==f"Track_{track}"]
middle = df_toplot_.loc[df_toplot_['LABEL']==f"Track_{track}.{end_clone[0]}"]
end = df_toplot_.loc[df_toplot_['LABEL']==f"Track_{track}.{end_clone}"]

df_toplot_ = pd.concat([root,middle,end])

plt.figure(figsize=(2,2), dpi=100)
sns.set_theme(style="ticks")


ax = sns.lineplot(x="time_hr", y="MEAN_INTENSITY_CH2",
             data=df_toplot_
                  , color=ingeo_colours[0]).set(ylim=(0,550), xlim=(52,96))

plt.xlabel(f'Time (hours)')
plt.ylabel(f'mean Achilles Expression')
plt.grid()  #just add this


plt.savefig(f'alltracks_mean_by_endstate_72.pdf', dpi = 300, bbox_inches='tight')

# %%
track = 183
end_clone = 'ab'

df_toplot_ = df_toplot.loc[df_toplot['TRACK_ID']==track]
root = df_toplot_.loc[df_toplot_['LABEL']==f"Track_{track}"]
middle = df_toplot_.loc[df_toplot_['LABEL']==f"Track_{track}.{end_clone[0]}"]
end = df_toplot_.loc[df_toplot_['LABEL']==f"Track_{track}.{end_clone}"]

df_toplot_ = pd.concat([root,middle,end])

plt.figure(figsize=(2,2), dpi=100)
sns.set_theme(style="ticks")


ax = sns.lineplot(x="time_hr", y="MEAN_INTENSITY_CH2",
             data=df_toplot_
                  , color=ingeo_colours[0]).set(ylim=(0,550), xlim=(52,96))

plt.xlabel(f'Time (hours)')
plt.ylabel(f'mean Achilles Expression')
plt.grid()  #just add this


plt.savefig(f'alltracks_mean_by_endstate_183.pdf', dpi = 300, bbox_inches='tight')

# %%
track = 213
end_clone = 'b'

df_toplot_ = df_toplot.loc[df_toplot['TRACK_ID']==track]
root = df_toplot_.loc[df_toplot_['LABEL']==f"Track_{track}"]
middle = df_toplot_.loc[df_toplot_['LABEL']==f"Track_{track}.{end_clone[0]}"]
end = df_toplot_.loc[df_toplot_['LABEL']==f"Track_{track}.{end_clone}"]

df_toplot_ = pd.concat([root,middle,end])

plt.figure(figsize=(2,2), dpi=100)
sns.set_theme(style="ticks")


ax = sns.lineplot(x="time_hr", y="MEAN_INTENSITY_CH2",
             data=df_toplot_
                  , color=ingeo_colours[4]).set(ylim=(0,550), xlim=(52,96))

plt.xlabel(f'Time (hours)')
plt.ylabel(f'mean Achilles Expression')
plt.grid()  #just add this


plt.savefig(f'alltracks_mean_by_endstate_213.pdf', dpi = 300, bbox_inches='tight')

# %%
plt.figure(figsize=(2,2), dpi=100)
sns.set_theme(style="ticks")


ax = sns.lineplot(x="time_hr", y="MEAN_INTENSITY_CH2",
             data=df_toplot.loc[df_toplot['TRACK_ID']==183]
                  , color=ingeo_colours[0]).set(ylim=(0,550), xlim=(52,96))

plt.xlabel(f'Time (hours)')
plt.ylabel(f'mean Achilles Expression')
plt.grid()  #just add this

# %%
plt.figure(figsize=(2,2), dpi=100)
sns.set_theme(style="ticks")


ax = sns.lineplot(x="time_hr", y="MEAN_INTENSITY_CH2",
             data=df_toplot.loc[df_toplot['TRACK_ID']==183]
                  , color=ingeo_colours[0]).set(ylim=(0,550), xlim=(52,96))

plt.xlabel(f'Time (hours)')
plt.ylabel(f'mean Achilles Expression')
plt.grid()  #just add this


plt.savefig(f'alltracks_mean_by_endstate_183.pdf', dpi = 300, bbox_inches='tight')
# Out:
# Index(['LABEL', 'ID', 'TRACK_ID', 'QUALITY', 'POSITION_X', 'POSITION_Y',
#        'POSITION_Z', 'POSITION_T', 'FRAME', 'RADIUS', 'VISIBILITY',
#        'MANUAL_SPOT_COLOR', 'MEAN_INTENSITY_CH1', 'MEDIAN_INTENSITY_CH1',
#        'MIN_INTENSITY_CH1', 'MAX_INTENSITY_CH1', 'TOTAL_INTENSITY_CH1',
#        'STD_INTENSITY_CH1', 'MEAN_INTENSITY_CH2', 'MEDIAN_INTENSITY_CH2',
#        'MIN_INTENSITY_CH2', 'MAX_INTENSITY_CH2', 'TOTAL_INTENSITY_CH2',
#        'STD_INTENSITY_CH2', 'CONTRAST_CH1', 'SNR_CH1', 'CONTRAST_CH2',
#        'SNR_CH2', 'ELLIPSE_X0', 'ELLIPSE_Y0', 'ELLIPSE_MAJOR', 'ELLIPSE_MINOR',
#        'ELLIPSE_THETA', 'ELLIPSE_ASPECTRATIO', 'AREA', 'PERIMETER',
#        'CIRCULARITY', 'SOLIDITY', 'SHAPE_INDEX', 'time_min', 'time_hr',
#        'Status', 'Batch', 'MEAN_INTENSITY_CH3', 'MEDIAN_INTENSITY_CH3',
#        'MIN_INTENSITY_CH3', 'MAX_INTENSITY_CH3', 'TOTAL_INTENSITY_CH3',
#        'STD_INTENSITY_CH3', 'CONTRAST_CH3', 'SNR_CH3'],
#       dtype='object')

# %%
plt.figure(figsize=(4,4), dpi=100)
sns.set_theme(style="ticks")


ax = sns.scatterplot(x="POSITION_T", y="MEAN_INTENSITY_CH2",
             hue="LABEL",
             data=df_toplot, palette ="muted")

plt.xlabel(f'Time (hours)')
plt.ylabel(f'mean Achilles Expression')
plt.grid()  #just add this

ax.get_legend().remove()

#plt.savefig(f'alltracks.png', dpi = 300, bbox_inches='tight')
