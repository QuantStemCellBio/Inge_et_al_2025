# %%
## DR ONLY


import pandas as pd
import seaborn as sns
import os
import glob as glob
import matplotlib.pyplot as plt


import pickle as pickle
import glob as glob
import numpy as np
import matplotlib.pyplot as plt
#from markov_simulator_dynamic_14March23_Jax_deep import Markov_fit
#from markov_simulator_dynamic_14March23_Jax_deep import make_extent
ingeo_colours = ["#0077BB","#33BBEE","#009988","#EE7733","#CC3311","#EE3377","#BBBBBB","#5D54A4"]

# %%
data = pd.read_csv("Residuals_and_features.csv")

# %%
data
# Out:
#      Topology_Name Topology_number  residual             hyp         AIC  \
# 0      MultipleE_4             T36  0.151167     MultipleE_4  -67.706072
# 1      MultipleE_1             T33  0.034985     MultipleE_1  -74.292825
# 2      MultipleM_1             T37  0.032893     MultipleM_1  -75.834176
# 3         Direct_1              T1  0.293390        Direct_1  -81.128245
# 4      MultipleE_2             T34  0.038530     MultipleE_2  -81.879904
# 5      MultipleM_2             T38  0.035156     MultipleM_2  -84.170559
# 6      MultipleE_3             T35  0.052243     MultipleE_3  -84.268034
# 7         Direct_3              T3  0.077399        Direct_3  -84.441386
# 8         Direct_2              T2  0.168558        Direct_2  -84.983742
# 9    MEandDirect_3             T17  0.096443   MEandDirect_3  -88.942091
# 10  MEandDirect_18             T32  0.040723  MEandDirect_18  -90.495675
# 11     MEclassic_1              T5  0.133237     MEclassic_1  -90.862513
# 12   MEandDirect_9             T23  0.059121   MEandDirect_9  -91.176134
# 13        Direct_4              T4  0.026249        Direct_4  -91.475246
# 14  MEandDirect_14             T28  0.021864  MEandDirect_14  -96.044279
# 15   MEandDirect_5             T19  0.031417   MEandDirect_5  -96.982020
# 16   MEandDirect_1             T15  0.046478   MEandDirect_1  -97.191149
# 17     MEclassic_4              T8  0.101949     MEclassic_4  -97.553885
# 18     MEclassic_3              T7  0.065781     MEclassic_3  -98.507426
# 19     MEclassic_8             T12  0.041521     MEclassic_8 -100.010863
# 20  MEandDirect_12             T26  0.041176  MEandDirect_12 -100.219336
# 21  MEandDirect_13             T27  0.017947  MEandDirect_13 -100.980706
# 22  MEandDirect_10             T24  0.026621  MEandDirect_10 -101.123445
# 23     MEclassic_9             T13  0.058935     MEclassic_9 -101.254758
# 24   MEandDirect_7             T21  0.039192   MEandDirect_7 -101.454109
# 25   MEandDirect_2             T16  0.053633   MEandDirect_2 -103.611551
# 26     MEclassic_5              T9  0.079129     MEclassic_5 -103.888881
# 27     MEclassic_6             T10  0.051720     MEclassic_6 -104.519642
# 28  MEandDirect_17             T31  0.022619  MEandDirect_17 -105.196231
# 29    MEclassic_10             T14  0.050339    MEclassic_10 -105.196420
# 30   MEandDirect_8             T22  0.033627   MEandDirect_8 -105.282269
# 31   MEandDirect_6             T20  0.031328   MEandDirect_6 -107.052792
# 32  MEandDirect_11             T25  0.030604  MEandDirect_11 -107.637207
# 33     MEclassic_2              T6  0.045574     MEclassic_2 -107.682474
# 34  MEandDirect_15             T29  0.020151  MEandDirect_15 -108.084347
# 35   MEandDirect_4             T18  0.019490   MEandDirect_4 -108.918578
# 36     MEclassic_7             T11  0.027235     MEclassic_7 -110.552950
# 37  MEandDirect_16             T30  0.015864  MEandDirect_16 -114.064824
#
#     N_params  Topology_num      hit Lineage convergence Endo_convergence  \
# 0         30            36  not hit                   Y                Y
# 1         45            33  not hit                   Y                Y
# 2         45            37  not hit                   N                N
# 3         15             1  not hit                   N                N
# 4         40            34  not hit                   Y                Y
# 5         40            38  not hit                   Y                Y
# 6         35            35  not hit                   Y                Y
# 7         30             3  not hit                   N                N
# 8         20             2  not hit                   N                N
# 9         25            17  not hit                   Y                N
# 10        35            32  not hit                   Y                N
# 11        20             5  not hit                   N                N
# 12        30            23  not hit                   Y                N
# 13        40             4  not hit                   N                N
# 14        40            28  not hit                   Y                Y
# 15        35            19  not hit                   Y                Y
# 16        30            15  not hit                   Y                Y
# 17        20             8  not hit                   N                N
# 18        25             7  not hit                   Y                N
# 19        30            12  not hit                   Y                N
# 20        30            26  not hit                   Y                N
# 21        40            27  not hit                   Y                Y
# 22        35            24  not hit                   Y                Y
# 23        25            13  not hit                   N                N
# 24        30            21  not hit                   Y                Y
# 25        25            16  not hit                   Y                Y
# 26        20             9  not hit                   N                N
# 27        25            10  not hit                   N                N
# 28        35            31  not hit                   Y                Y
# 29        25            14  not hit                   N                N
# 30        30            22  not hit                   Y                Y
# 31        30            20  not hit                   Y                Y
# 32        30            25  not hit                   Y                Y
# 33        25             6      hit                   Y                Y
# 34        35            29      hit                   Y                Y
# 35        35            18      hit                   Y                Y
# 36        30            11      hit                   Y                Y
# 37        35            30      hit                   Y                Y
#
#    Meso_convergence EtM MtE EorMorB
# 0                 N   N   Y       E
# 1                 N   N   Y       E
# 2                 N   N   N       N
# 3                 N   N   Y       N
# 4                 N   N   N       E
# 5                 Y   N   Y       B
# 6                 N   N   N       E
# 7                 N   N   N       N
# 8                 N   N   N       N
# 9                 Y   N   N       M
# 10                Y   Y   N       M
# 11                N   N   N       N
# 12                Y   Y   N       M
# 13                N   N   N       N
# 14                Y   Y   N       B
# 15                Y   Y   N       B
# 16                Y   N   N       B
# 17                N   N   Y       N
# 18                Y   Y   N       M
# 19                Y   Y   N       M
# 20                Y   N   N       M
# 21                Y   N   Y       E
# 22                Y   N   N       E
# 23                N   N   Y       N
# 24                Y   N   Y       B
# 25                N   N   N       E
# 26                N   Y   N       N
# 27                N   N   N       N
# 28                Y   Y   N       B
# 29                N   Y   N       N
# 30                Y   Y   N       B
# 31                N   N   Y       E
# 32                N   N   N       E
# 33                N   N   Y       E
# 34                N   N   Y       E
# 35                Y   N   Y       B
# 36                N   N   Y       E
# 37                Y   N   Y       B

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

subset = data

parameter = "Lineage convergence"

se_values = subset.groupby(parameter)["AIC"].sem()

# Assuming 'data' is a pandas DataFrame containing your data
# Calculate the standard error for each group
# Calculate means for each group
means = subset.groupby(parameter)["AIC"].mean()

# Add error bars for standard error (SE) at the means
plt.errorbar(means.index, means, yerr=se_values, fmt='o', color='black', capsize=5)


# Show the plot
plt.show()

# %%
plt.figure(figsize=(1,4), dpi=100)

sns.set_theme(style="ticks")


se_values = subset.groupby(parameter)["AIC"].sem()

# Assuming 'data' is a pandas DataFrame containing your data
# Calculate the standard error for each group
# Calculate means for each group
means = subset.groupby(parameter)["AIC"].mean()

# Add error bars for standard error (SE) at the means
plt.errorbar(means.index, means, yerr=se_values, fmt='o', color='black', capsize=5)


sns.stripplot(data=subset, y="AIC", x=parameter, order=['N','Y'], palette=['grey','orange'])
plt.savefig("Convergence_yes_no.pdf", dpi=1000)
# Out:
# <ipython-input-18-28f9ff0ef3b6>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=subset, y="AIC", x=parameter, order=['N','Y'], palette=['grey','orange'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

subset = data.loc[data["Lineage convergence"]=='Y']

parameter = "MtE"

se_values = subset.groupby(parameter)["AIC"].sem()

# Assuming 'data' is a pandas DataFrame containing your data
# Calculate the standard error for each group
# Calculate means for each group
means = subset.groupby(parameter)["AIC"].mean()

# Add error bars for standard error (SE) at the means
plt.errorbar(means.index, means, yerr=se_values, fmt='o', color='black', capsize=5)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

subset = data.loc[data["Lineage convergence"]=='Y']

parameter = "MtE"

se_values = subset.groupby(parameter)["AIC"].sem()

# Assuming 'data' is a pandas DataFrame containing your data
# Calculate the standard error for each group
# Calculate means for each group
means = subset.groupby(parameter)["AIC"].mean()

# Add error bars for standard error (SE) at the means
plt.errorbar(means.index, means, yerr=se_values, fmt='o', color='black', capsize=5)

# Show the plot
plt.show()
